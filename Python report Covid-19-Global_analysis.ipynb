# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
df = pd.read_csv("01.04_global.csv")

# I'm going to create graphs to analize cases of COVID-19 in S.Korea by April 1st 2020 

df.head(5)
# Out:
#   State      Country      Lat     Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0   NaN  Afghanistan  33.0000  65.0000        0        0        0        0
# 1   NaN      Albania  41.1533  20.1683        0        0        0        0
# 2   NaN      Algeria  28.0339   1.6596        0        0        0        0
# 3   NaN      Andorra  42.5063   1.5218        0        0        0        0
# 4   NaN       Angola -11.2027  17.8739        0        0        0        0
#
#    1/26/20  1/27/20  ...  3/22/20  3/23/20  3/24/20  3/25/20  3/26/20  \
# 0        0        0  ...       40       40       74       84       94
# 1        0        0  ...       89      104      123      146      174
# 2        0        0  ...      201      230      264      302      367
# 3        0        0  ...      113      133      164      188      224
# 4        0        0  ...        2        3        3        3        4
#
#    3/27/20  3/28/20  3/29/20  3/30/20  3/31/20
# ...

# %%
df_1 = df.drop(['State', 'Lat', 'Long'], axis = 1) 
df_1.head(5)
# Out:
#        Country  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# 0  Afghanistan        0        0        0        0        0        0        0
# 1      Albania        0        0        0        0        0        0        0
# 2      Algeria        0        0        0        0        0        0        0
# 3      Andorra        0        0        0        0        0        0        0
# 4       Angola        0        0        0        0        0        0        0
#
#    1/29/20  1/30/20  ...  3/22/20  3/23/20  3/24/20  3/25/20  3/26/20  \
# 0        0        0  ...       40       40       74       84       94
# 1        0        0  ...       89      104      123      146      174
# 2        0        0  ...      201      230      264      302      367
# 3        0        0  ...      113      133      164      188      224
# 4        0        0  ...        2        3        3        3        4
#
#    3/27/20  3/28/20  3/29/20  3/30/20  3/31/20
# ...

# %%
df_1 = df_1.sort_values(by=['3/31/20'], ascending=False)
df_1
# Out:
#               Country  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 225                US        1        1        2        2        5        5
# 137             Italy        0        0        0        0        0        0
# 201             Spain        0        0        0        0        0        0
# 120           Germany        0        0        0        0        0        1
# 62              China      444      444      549      761     1058     1423
# ..                ...      ...      ...      ...      ...      ...      ...
# 78              China        0        0        0        0        0        0
# 179  Papua New Guinea        0        0        0        0        0        0
# 236       Timor-Leste        0        0        0        0        0        0
# 238            Canada        0        0        0        0        0        0
# 231            Canada        0        0        0        0        0        0
#
# ...

# %%
df_1 = df_1[:10]
df_1
# Out:
#             Country  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 225              US        1        1        2        2        5        5
# 137           Italy        0        0        0        0        0        0
# 201           Spain        0        0        0        0        0        0
# 120         Germany        0        0        0        0        0        1
# 62            China      444      444      549      761     1058     1423
# 116          France        0        0        2        3        3        3
# 133            Iran        0        0        0        0        0        0
# 223  United Kingdom        0        0        0        0        0        0
# 206     Switzerland        0        0        0        0        0        0
# 213          Turkey        0        0        0        0        0        0
#
#      1/28/20  1/29/20  1/30/20  ...  3/22/20  3/23/20  3/24/20  3/25/20  \
# 225        5        5        5  ...    33276    43847    53740    65778
# ...

# %%
df_global = df_1.pivot_table(columns = 'Country') # Dataframe for graph 'Top-10  countries with COVID-19-cases by April 1st 2020'
df_global
# Out:
# Country  China  France  Germany  Iran  Italy  Spain  Switzerland  Turkey   US  \
# 1/22/20    444       0        0     0      0      0            0       0    1
# 1/23/20    444       0        0     0      0      0            0       0    1
# 1/24/20    549       2        0     0      0      0            0       0    2
# 1/25/20    761       3        0     0      0      0            0       0    2
# 1/26/20   1058       3        0     0      0      0            0       0    5
# ...        ...     ...      ...   ...    ...    ...          ...     ...  ...
# 3/5/20   67466     377      482  3513   3858    259          114       0  217
# 3/6/20   67592     653      670  4747   4636    400          214       0  262
# 3/7/20   67666     949      799  5823   5883    500          268       0  402
# 3/8/20   67707    1126     1040  6566   7375    673          337       0  518
# 3/9/20   67743    1209     1176  7161   9172   1073          374       0  583
#
# Country  United Kingdom
# ...

# %%
df_global = df_global.reset_index()
df_global
# Out:
# Country    index  China  France  Germany  Iran  Italy  Spain  Switzerland  \
# 0        1/22/20    444       0        0     0      0      0            0
# 1        1/23/20    444       0        0     0      0      0            0
# 2        1/24/20    549       2        0     0      0      0            0
# 3        1/25/20    761       3        0     0      0      0            0
# 4        1/26/20   1058       3        0     0      0      0            0
# ..           ...    ...     ...      ...   ...    ...    ...          ...
# 65        3/5/20  67466     377      482  3513   3858    259          114
# 66        3/6/20  67592     653      670  4747   4636    400          214
# 67        3/7/20  67666     949      799  5823   5883    500          268
# 68        3/8/20  67707    1126     1040  6566   7375    673          337
# 69        3/9/20  67743    1209     1176  7161   9172   1073          374
#
# Country  Turkey   US  United Kingdom
# 0             0    1               0
# ...

# %%
df_global = df_global.rename(columns = {'index': 'Date'})
df_global
# Out:
# Country     Date  China  France  Germany  Iran  Italy  Spain  Switzerland  \
# 0        1/22/20    444       0        0     0      0      0            0
# 1        1/23/20    444       0        0     0      0      0            0
# 2        1/24/20    549       2        0     0      0      0            0
# 3        1/25/20    761       3        0     0      0      0            0
# 4        1/26/20   1058       3        0     0      0      0            0
# ..           ...    ...     ...      ...   ...    ...    ...          ...
# 65        3/5/20  67466     377      482  3513   3858    259          114
# 66        3/6/20  67592     653      670  4747   4636    400          214
# 67        3/7/20  67666     949      799  5823   5883    500          268
# 68        3/8/20  67707    1126     1040  6566   7375    673          337
# 69        3/9/20  67743    1209     1176  7161   9172   1073          374
#
# Country  Turkey   US  United Kingdom
# 0             0    1               0
# ...

# %%
from natsort import index_natsorted, order_by_index
df_global= df_global.reindex(index = order_by_index(df_2.index, index_natsorted(df_2['Date'], reverse=False)))
df_global
# Out:
# Country     Date  China  France  Germany   Iran   Italy  Spain  Switzerland  \
# 0        1/22/20    444       0        0      0       0      0            0
# 1        1/23/20    444       0        0      0       0      0            0
# 2        1/24/20    549       2        0      0       0      0            0
# 3        1/25/20    761       3        0      0       0      0            0
# 4        1/26/20   1058       3        0      0       0      0            0
# ..           ...    ...     ...      ...    ...     ...    ...          ...
# 58       3/27/20  67801   32964    50871  32332   86498  65719        12928
# 59       3/28/20  67801   37575    57695  35408   92472  73235        14076
# 60       3/29/20  67801   40174    62095  38309   97689  80110        14829
# 62       3/30/20  67801   44550    66885  41495  101739  87956        15922
# 63       3/31/20  67801   52128    71808  44605  105792  95923        16605
#
# Country  Turkey      US  United Kingdom
# ...

# %%
df_time = pd.read_csv("Time.csv") # open file with data about health condition of patients from 2020/01/20 to 2020/03/31
df_time.head(5)
# Out:
#          date  time  test  negative  confirmed  released  deceased
# 0  2020-01-20    16     1         0          1         0         0
# 1  2020-01-21    16     1         0          1         0         0
# 2  2020-01-22    16     4         3          1         0         0
# 3  2020-01-23    16    22        21          1         0         0
# 4  2020-01-24    16    27        25          2         0         0

# %%
df_SK= df_time.drop(['time', 'test', 'negative'], axis = 1)   # Dataframe for graph 'Case rates by state of COVID-19 cases in S.Korea by April 1st 2020'
df_SK
# Out:
#           date  confirmed  released  deceased
# 0   2020-01-20          1         0         0
# 1   2020-01-21          1         0         0
# 2   2020-01-22          1         0         0
# 3   2020-01-23          1         0         0
# 4   2020-01-24          2         0         0
# ..         ...        ...       ...       ...
# 66  2020-03-26       9241      4144       131
# 67  2020-03-27       9332      4528       139
# 68  2020-03-28       9478      4811       144
# 69  2020-03-29       9583      5033       152
# 70  2020-03-30       9661      5228       158
#
# [71 rows x 4 columns]

# %%
import matplotlib.ticker as ticker


fig = plt.figure()

ax_1 = fig.add_subplot(1, 2, 1)    # number of graph's columns and rows
ax_2 = fig.add_subplot(1, 2, 2)

fig.set_figwidth(16)
fig.set_figheight(4)



ax_1.xaxis.set_major_locator(ticker.MultipleLocator(9))  # Graph 'Top-10  countries with COVID-19-cases by April 1st 2020'
ax_1.xaxis.set_minor_locator(ticker.MultipleLocator(1))

x = df_global['Date']
y_China = df_global['China']
y_France = df_global['France']
y_Germany = df_global['Germany']
y_Iran = df_global['Iran']
y_Italy = df_global['Italy']
y_Spain = df_global['Spain']
y_Switzerland = df_global['Switzerland']
y_US = df_global['US']
y_United_Kingdom = df_global['United Kingdom']

ax_1.plot(x,y_China, label = "China")      
ax_1.plot(x,y_France, label = "France")
ax_1.plot(x,y_Germany, label = "Germany")
ax_1.plot(x,y_Iran, label = "Iran")
ax_1.plot(x,y_Italy, label = "Italy")
ax_1.plot(x,y_Spain, label = "Spain")
ax_1.plot(x,y_Switzerland, label = "Switzerland")
ax_1.plot(x,y_US, label = "US")
ax_1.plot(x,y_United_Kingdom, label = "United Kingdom")

ax_1.set_xlabel('Date')
ax_1.set_ylabel('Amount of cases')
ax_1.set_title('Top-10  countries with COVID-19-cases by April 1st 2020')

ax_1.legend(loc = "best")




ax_2.xaxis.set_major_locator(ticker.MultipleLocator(12))  # Graph 'Case rates by state of COVID-19 cases in S.Korea by April 1st 2020'
ax_2.xaxis.set_minor_locator(ticker.MultipleLocator(1))


y_confirmed = df_SK['confirmed']
y_released = df_SK['released']
y_deceased = df_SK['deceased']
x = df_SK['date']


ax_2.plot(x,y_confirmed, label = "confirmed")
ax_2.plot(x,y_released, label = "released")
ax_2.plot(x,y_deceased, label = "deceased")

ax_2.set_xlabel('Date')
ax_2.set_ylabel('Amount of cases')
ax_2.set_title('Case rates by state of COVID-19 cases in S.Korea by April 1st 2020')

ax_2.legend(loc = "best")

plt.show()
